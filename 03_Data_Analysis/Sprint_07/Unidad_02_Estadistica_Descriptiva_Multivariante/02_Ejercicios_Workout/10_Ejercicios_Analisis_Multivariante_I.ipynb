# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Para ejercitarte y afianzar lo aprendido sobre el análisis bivariante, completa los siguientes ejercicios. Recuerda que necesitarás datos que están en el directorio data que acompaña al notebook (búscalo en el repositorio de ejercicios)
#
# La solución a los mismos se subirá a lo largo del sprint.

# %% [markdown]
# ### Ejercicio 0
#
#
# Importa los paquetes y módulos que necesites a lo largo del notebook

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from bootcampviztools import plot_categorical_numerical_relationship, plot_combined_graphs, \
    pinta_distribucion_categoricas, plot_grouped_boxplots, plot_grouped_histograms, plot_categorical_relationship_fin, grafico_dispersion_con_correlacion # Este módulo lo tienes en el directorio de los notebooks, puede abrirlo y jugar con las funciones que contiene

# %% [markdown]
# ### Ejercicio 1

# %% [markdown]
# Carga el dataset de admisiones que conoces de la unidad anterior y que se encuentra en la ruta "./data/admission_data.csv", deshazte de las columnas innecesarias

# %%
df = pd.read_csv("./data/admission_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Year                    Major Gender Admission
# 0           0  1973       School of Medicine      F  Rejected
# 1           1  1973  Department of Economics      M  Accepted
# 2           2  1973                    Other      F  Accepted
# 3           3  1973                    Other      M  Accepted
# 4           4  1973                    Other      M  Rejected

# %%
df = df.drop(columns="Unnamed: 0")
df
# Out:
#        Year                                 Major Gender Admission
# 0      1973                    School of Medicine      F  Rejected
# 1      1973               Department of Economics      M  Accepted
# 2      1973                                 Other      F  Accepted
# 3      1973                                 Other      M  Accepted
# 4      1973                                 Other      M  Rejected
# ...     ...                                   ...    ...       ...
# 12758  1973                                 Other      M  Accepted
# 12759  1973  Department of Mechanical Engineering      M  Accepted
# 12760  1973                                 Other      F  Rejected
# 12761  1973                                 Other      M  Rejected
# 12762  1973                                 Other      M  Accepted
#
# [12763 rows x 4 columns]

# %% [markdown]
# ### Ejercicio 2

# %% [markdown]
# Haz el análisis bivariante de "Admission" y "Major" (emplea las funciones del workout importándolas del módulo `bootcampviztools`, o utiliza las visualizaciones del notebook en el repositorio) y contesta a las siguientes preguntas:
# * ¿Cuál es el departamento con el mayor porcentaje de admsiones?¿Y el de menor?
# * ¿Existe alguna diferencia destacada entre los departamentos?

# %%
pinta_distribucion_categoricas(df,["Admission"], relativa = True)

# %%
pinta_distribucion_categoricas(df,["Major"], relativa = True)

# %%
plot_categorical_relationship_fin(df,"Major","Admission", show_values= True, relative_freq = True)

# %%
# al que más aceptan es a los estudiantes de física y astronomía, psicología la que menos
# si, parece haber una clara diferencia de aceptar y rechazar en base al departamento

# %% [markdown]
# ### Ejercicio 3
#
# Repite el análisis para "Admission" y "Gender" y responde a las siguientes preguntas:
# * ¿Existe una diferencia visual significativa entre el porcentaje de admitidos de cada género?
# * ¿Cuál de los dos grupos tiene más admisiones?

# %%
pinta_distribucion_categoricas(df,["Gender"], relativa = True)

# %%
plot_categorical_relationship_fin(df,"Gender","Admission", show_values= True, relative_freq = True)

# %%
# pese a que es mucho menor que en el caso del departamento, si existe una diferencia significativa visual entre los aceptados por genero
# los hombres son admitidos un 9% mas, esto podría estar mediado por la carrera elegida
# los hombres tienen más admisiones, son mas y tienen un mayor porcentaje

# %% [markdown]
# ### Ejercicio 4
#
# Carga el dataset de propinas (tips) que conoces de la unidad anterior y que se encuentra en la ruta "./data/tips.csv", deshazte de las columnas innecesarias

# %%
df2 = pd.read_csv("./data/tips.csv")
df2 = df2.drop(columns="Unnamed: 0")
df2
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### Ejercicio 5
#
# Haz el análisis bivariante de "tip" y "sex" (emplea las funciones del workout importándolas del módulo `bootcampviztools`, o utiliza las visualizaciones del notebook en el repositorio), añade el cálculo de la media y mediana de la variable continua por cada valor de la variable categórica, y contesta a las siguientes preguntas:
# * ¿Existe alguna diferencia visualmente significativa entre las propinas de los grupos de la variable "sex"?
# * ¿Son diferentes respecto al  conjunto total?

# %%
plot_categorical_numerical_relationship(df2,"sex","tip", show_values= True, measure= "median")

# %%
plot_grouped_boxplots(df2, "sex","tip")

# %%
plot_grouped_histograms(df2,"sex", "tip", 2)

# %%
# si, parece que los hombres dan mayores propinas en general que las mujeres, además en el grupo de los hombres hay
# outlayers que dan propinas bastantes mayores, mientras que en el de mujeres no

# %% [markdown]
# ### Ejercicio 6
#
# Repite el análisis pero esta vez para "tip" y "smoker", añade también el cálculo de la media y de la mediana de la variable continua por cada valor de la variable categórica, y contesta a las siguiente pregunta:
# * ¿Existe alguna diferencia visualmente significativa entre las propinas de los grupos de la variable "smoker"?

# %%
plot_categorical_numerical_relationship(df2,"smoker","tip", show_values= True, measure= "median")

# %%
plot_grouped_boxplots(df2, "smoker","tip")

# %%
df2[df2["smoker"]=="No"]["tip"].describe()
# Out:
# count    151.000000
# mean       2.991854
# std        1.377190
# min        1.000000
# 25%        2.000000
# 50%        2.740000
# 75%        3.505000
# max        9.000000
# Name: tip, dtype: float64

# %%
df2[df2["smoker"]=="Yes"]["tip"].describe()
# Out:
# count    93.000000
# mean      3.008710
# std       1.401468
# min       1.000000
# 25%       2.000000
# 50%       3.000000
# 75%       3.680000
# max      10.000000
# Name: tip, dtype: float64

# %%
plot_grouped_histograms(df2,"smoker", "tip", 2)

# %%
# no son significativas pero si hay diferencias, parece que los fumadores dan un poco más de propinas, pero en este caso tienen menos outlayers,
# por lo que las mayores propinas son de no fumadores, aunque en promedio den mas

# %% [markdown]
# ### Ejericicio 7
#
# Carga ahora el datase de accidentes de coches, que se encuentra en la ruta "./data/car_crashes.csv" y deshazte de las columnas innecesarias

# %%
df3 = pd.read_csv("./data/car_crashes.csv", sep="|")
df3 = df3.drop(columns = ["Unnamed: 0"])
df3
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# 12   15.3     5.508    4.437          13.005       14.994       641.96
# 13   12.8     4.608    4.352          12.032       12.288       803.11
# 14   14.5     3.625    4.205          13.775       13.775       710.46
# 15   15.7     2.669    3.925          15.229       13.659       649.06
# 16   17.8     4.806    4.272          13.706       15.130       780.45
# 17   21.4     4.066    4.922          16.692       16.264       872.51
# 18   20.5     7.175    6.765          14.965       20.090      1281.55
# 19   15.1     5.738    4.530          13.137       12.684       661.88
# 20   12.5     4.250    4.000           8.875       12.375      1048.78
# 21    8.2     1.886    2.870           7.134        6.560      1011.14
# 22   14.1     3.384    3.948          13.395       10.857      1110.61
# 23    9.6     2.208    2.784           8.448        8.448       777.18
# 24   17.6     2.640    5.456           1.760       17.600       896.07
# 25   16.1     6.923    5.474          14.812       13.524       790.32
# 26   21.4     8.346    9.416          17.976       18.190       816.21
# 27   14.9     1.937    5.215          13.857       13.410       732.28
# 28   14.7     5.439    4.704          13.965       14.553      1029.87
# 29   11.6     4.060    3.480          10.092        9.628       746.54
# 30   11.2     1.792    3.136           9.632        8.736      1301.52
# 31   18.4     3.496    4.968          12.328       18.032       869.85
# 32   12.3     3.936    3.567          10.824        9.840      1234.31
# 33   16.8     6.552    5.208          15.792       13.608       708.24
# 34   23.9     5.497   10.038          23.661       20.554       688.75
# 35   14.1     3.948    4.794          13.959       11.562       697.73
# 36   19.9     6.368    5.771          18.308       18.706       881.51
# 37   12.8     4.224    3.328           8.576       11.520       804.71
# 38   18.2     9.100    5.642          17.472       16.016       905.99
# 39   11.1     3.774    4.218          10.212        8.769      1148.99
# 40   23.9     9.082    9.799          22.944       19.359       858.97
# 41   19.4     6.014    6.402          19.012       16.684       669.31
# 42   19.5     4.095    5.655          15.990       15.795       767.91
# 43   19.4     7.760    7.372          17.654       16.878      1004.75
# 44   11.3     4.859    1.808           9.944       10.848       809.38
# 45   13.6     4.080    4.080          13.056       12.920       716.20
# 46   12.7     2.413    3.429          11.049       11.176       768.95
# 47   10.6     4.452    3.498           8.692        9.116       890.03
# 48   23.8     8.092    6.664          23.086       20.706       992.61
# 49   13.8     4.968    4.554           5.382       11.592       670.31
# 50   17.4     7.308    5.568          14.094       15.660       791.14
#
#     ins_losses abbrev
# 0       145.08     AL
# 1       133.93     AK
# 2       110.35     AZ
# 3       142.39     AR
# 4       165.63     CA
# 5       139.91     CO
# 6       167.02     CT
# 7       151.48     DE
# 8       136.05     DC
# 9       144.18     FL
# 10      142.80     GA
# 11      120.92     HI
# 12       82.75     ID
# 13      139.15     IL
# 14      108.92     IN
# 15      114.47     IA
# 16      133.80     KS
# 17      137.13     KY
# 18      194.78     LA
# 19       96.57     ME
# 20      192.70     MD
# 21      135.63     MA
# 22      152.26     MI
# 23      133.35     MN
# 24      155.77     MS
# 25      144.45     MO
# 26       85.15     MT
# 27      114.82     NE
# 28      138.71     NV
# 29      120.21     NH
# 30      159.85     NJ
# 31      120.75     NM
# 32      150.01     NY
# 33      127.82     NC
# 34      109.72     ND
# 35      133.52     OH
# 36      178.86     OK
# 37      104.61     OR
# 38      153.86     PA
# 39      148.58     RI
# 40      116.29     SC
# 41       96.87     SD
# 42      155.57     TN
# 43      156.83     TX
# 44      109.48     UT
# 45      109.61     VT
# 46      153.72     VA
# 47      111.62     WA
# 48      152.56     WV
# 49      106.62     WI
# 50      122.04     WY

# %% [markdown]
# ### Ejercicio 8
#
# Haz un analisis bivairante entre "total" y "speeding". Muestra su diagrama de dispersión y su valor de correlación de pearson obtenido con pandas. Luego contesta a la siguiente pregunta
# * ¿Existe alguna relación visual entre las variables?¿Y numérica?

# %%
grafico_dispersion_con_correlacion(df3,"total","speeding", 20, mostrar_correlacion = True)

# %%
# si, parece que la velocidad y el total de accidentes guardan una relacion directamente proporcional

# %% [markdown]
# ### Ejercicio 9
#
# Usa scipy tal como lo hicimos en el workout para hacer el test de correlación. ¿Cuál es el p-value?¿Qué podemos decir de la correlación lineal entre "total" y "speeding"?

# %%
from scipy.stats import pearsonr

pearsonr(df3["speeding"], df3["total"])
# Out:
# PearsonRResult(statistic=np.float64(0.6115476008001186), pvalue=np.float64(1.8670391109056657e-06))

# %%
# que es estadisticamente significativa, además de bastante fuerte (0,6)
