# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Para ejercitarte y afianzar lo aprendido sobre **DBSCAN**, completa los siguientes ejercicios. Recuerda que necesitarás datos que están en el directorio data que acompaña al notebook (búscalo en el repositorio de ejercicios)
#
# La solución a los mismos las tienes ya, intenta no mirarlos de primeras pero no dejes de hacerlo cuando hayas terminado por si te pudieran aportar.

# %% [markdown]
# ### Problema y "justificación": DBSCAN

# %% [markdown]
# Como sabemos, existen diversas técnicas de clusterización comprendidas por algoritmos de machine learning no supervisados, cuya finalidad es agrupar distintos elementos de una data sin la necesidad de estar previamente etiquetados.
#
# Anteriormente utilizamos el algoritmo de KMeans, sin embargo, dicho algoritmo tiene algunas limitaciones, como el hecho de que no siempre es sencillo obtener un número de K clusters óptimo o que algunas distribuciones de datos no se ajustan a la agrupación por clusters debido a la naturaleza del algoritmo. Para estos casos existen diversos algoritmos de clusterización.
#
# A continuación, vamos a utilizar el algoritmo DBSCAN (Density-Based Spatial Clustering of Applications with Noise) para capturar grupos en data con patrones relativamente complejos.
#
# Utilizaremos data de clientes de un distribuidor al por mayor, en el que se recogen por línea ventas a diferentes establecimientos y empresas de sus productos (aunque no se incluye el identificador de establecimiento) y cuyo objetivo es obtener agrupacioines interesantes (agrupaciones no predefinidas de productos que se suelen comprar juntos):

# %% [markdown]
# Features:
#
#     1) FRESH: Gastos en productos frescos;
#     2) MILK: Gastos en productos lacteos;
#     3) GROCERY: Gastos en comestibles;
#     4) FROZEN: Gastos en congelados;
#     5) DETERGENTS_PAPER: Gastos en detergentes y derivados del papel;
#     6) DELICATESSEN: Gatos en comestibles finos;
#     7) CHANNEL: Canal que utilizan los clientes para vender - Horeca (Hotel/Restaurant/Cafeterías) o Retail channel (Al por menor);
#     8) REGION: Región del cliente;

# %% [markdown]
# Fuente: https://archive.ics.uci.edu/ml/datasets/Wholesale+customers

# %% [markdown]
# ### Ejercicio 0

# %% [markdown]
# Importa los paquetes y módulos que necesites a lo largo del notebook

# %%
# Common imports
import numpy as np
import seaborn as sns
from sklearn.cluster import DBSCAN
# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# Ignore useless warnings (see SciPy issue #5998)
import warnings
warnings.filterwarnings(action="ignore", message="^internal gelsd")

# %%
import pandas as pd

# %% [markdown]
# ### Ejercicio 1

# %% [markdown]
# Carga los datos y haz una primera exploración, incluyendo una descripción de las variables numéricas.

# %%
df = pd.read_csv("./data/wholesale-customers-data.csv")

# %%
df
# Out:
#      Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 0          2       3  12669   9656     7561     214              2674
# 1          2       3   7057   9810     9568    1762              3293
# 2          2       3   6353   8808     7684    2405              3516
# 3          1       3  13265   1196     4221    6404               507
# 4          2       3  22615   5410     7198    3915              1777
# ..       ...     ...    ...    ...      ...     ...               ...
# 435        1       3  29703  12051    16027   13135               182
# 436        1       3  39228   1431      764    4510                93
# 437        2       3  14531  15488    30243     437             14841
# 438        1       3  10290   1981     2232    1038               168
# 439        1       3   2787   1698     2510      65               477
#
#      Delicassen
# 0          1338
# 1          1776
# 2          7844
# 3          1788
# 4          5185
# ..          ...
# 435        2204
# 436        2346
# 437        1867
# 438        2125
# 439          52
#
# [440 rows x 8 columns]

# %% [markdown]
# $$***$$

# %% [markdown]
# Es hora de hacer un miniEda (cuyo objetivo en el caso de clusterizacion no es obtener features para predicción de un target que no tenemos), cuyo objetivo es poder intuir posibles agrupaciones y su número, detectar si hay que hacer transformaciones y escalado en las variables y cuál

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Channel           440 non-null    int64
#  1   Region            440 non-null    int64
#  2   Fresh             440 non-null    int64
#  3   Milk              440 non-null    int64
#  4   Grocery           440 non-null    int64
#  5   Frozen            440 non-null    int64
#  6   Detergents_Paper  440 non-null    int64
#  7   Delicassen        440 non-null    int64
# dtypes: int64(8)
# memory usage: 27.6 KB

# %% [markdown]
# ### Ejercicio 2

# %% [markdown]
# Pinta el histograma de las variables y determina cuáles podríamos considerar numéricas continuas y cuáles numéricas discretas (o categóricas)

# %%
for columna in df.columns:
    plt.figure()
    sns.histplot(df[columna])
    plt.title(columna)
    plt.show()

# %%
df.columns
# Out:
# Index(['Channel', 'Region', 'Fresh', 'Milk', 'Grocery', 'Frozen',
#        'Detergents_Paper', 'Delicassen'],
#       dtype='object')

# %%
categoricas = ['Channel', 'Region']
numericas =[ 'Fresh', 'Milk', 'Grocery', 'Frozen',
       'Detergents_Paper', 'Delicassen']

# %% [markdown]
# ### Ejercicio 3
#
# Antes de decidir sobre las agrupaciones, vamos pintar los histrogramas pero separando por canal (ya que es un elemento muy diferenciador del tipo de venta que se realiza a mayorista). Muestra graficamente para cada variable numérica su histograma para cada canal (Horeca y Retail).

# %%
import bootcampviztools as bt

# %%
for columna in df[numericas]:
    plt.figure()
    bt.plot_grouped_histograms(df,"Channel",columna, group_size=len(numericas))
    plt.title(columna)
    plt.show()

# %% [markdown]
# ### Ejercicio 4
#
# Analicemos los outliers. Obten los outliers a partir de los diagramas de boxplot para todos los datos y luego separados por canal.

# %%
for columna in df[numericas].columns:
    plt.figure()
    sns.boxplot(df[columna])
    plt.title(columna)
    plt.show()

# %% [markdown]
# ### Ejercicio 5
#
# Vamos a intentar detectar posibles agrupaciones en los datos con variables dos a dos. Utiliza un pairplot de sns para mostrar los scatter plots de las variables numéricas dos a dos e intentar visualizar algún clustering e incluso justificar usar kMeans o DBSCAN. En este ejercicio hazlo para todo el dataset.

# %%
sns.pairplot(df[numericas])

# %% [markdown]
# ### Ejercicio 6
#
# Repite el ejercicio 5 pero separando por canal. Emplea el argumento hue del pairplot para no tener que hacer dos pairplots diferentes.

# %%
sns.pairplot(df, hue="Channel")

# %% [markdown]
# ### Ejercicio 7
#
# Si has logrado hacer los dos ejercicios anteriores (y si no consulta su solución) tendrás una idea un poco más clara de por qué es interesante la clusterización con DBSCAN mejor que con KMeans. Así que vamos a utilizarlo, pero antes escalemos los datos, transformándolos primero (de primeras no vamos a distinguir entre canales, hazlo con todo el dataseet). Es decir aplica la tranformación que creas necesaria en las columnas numéricas que creas conveniente. Hazlo en un dataframe copiado del original para poder interpretar los valores correctamente al final.

# %%
sns.histplot(df)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# ### Ejercicio 8
#
# Escala las columnas que creas necesario. Si no lo tienes claro, escala todas.

# %%
categoricas
# Out:
# ['Channel', 'Region']

# %%
df_escalado = df[numericas].apply(lambda x: np.log(x))

# %%
from sklearn.preprocessing import StandardScaler

# %%
escalador = StandardScaler()

# %%
df_escalado=pd.DataFrame(escalador.fit_transform(df_escalado),columns=df_escalado.columns, index=df_escalado.index)

# %%
df_escalado[['Channel', 'Region']]=df[categoricas]

# %%
df_escalado
# Out:
#         Fresh      Milk   Grocery    Frozen  Detergents_Paper  Delicassen  \
# 0    0.484561  0.976070  0.439132 -1.508418          0.643001    0.407685
# 1    0.088766  0.990718  0.650291  0.134683          0.764127    0.623967
# 2    0.017680  0.890970  0.453606  0.377147          0.802243    1.758420
# 3    0.515656 -0.957573 -0.083722  1.140446         -0.324282    0.629110
# 4    0.876512  0.439720  0.395003  0.756909          0.405285    1.442246
# ..        ...       ...       ...       ...               ...         ...
# 435  1.060925  1.181199  1.112977  1.700316         -0.920248    0.788867
# 436  1.249064 -0.791491 -1.616824  0.867177         -1.310814    0.836554
# 437  0.577315  1.413502  1.682525 -0.951977          1.639949    0.662131
# 438  0.343877 -0.490392 -0.655228 -0.277726         -0.966810    0.760989
# 439 -0.539657 -0.633106 -0.549941 -2.437112         -0.359763   -2.072714
#
#      Channel  Region
# 0          2       3
# 1          2       3
# 2          2       3
# 3          1       3
# 4          2       3
# ..       ...     ...
# 435        1       3
# 436        1       3
# 437        2       3
# 438        1       3
# 439        1       3
#
# [440 rows x 8 columns]

# %% [markdown]
# ### Ejercicio 9
#
# En el caso de los modelos no supervisados, una vez hemos tratado las features hay que escoger los hiperparámetros. En el caso de dBSCAN no es el número de clústeres, sino la distancia `eps` que determina el vecindario de un punto y el número de vecinos a partir del cual se decide si una instancia es core o no (`min_samples`).
#
# Una forma de hacerlo es iterar sobre rangos de estos dos hiperparámetros midiendo el porentaje de "anomalías" que detecta y considerando como punto de parada un valor por debajo del 10%.
#
# NOTA: Usa el doble de cantidad de tus features para el mínimo de elementos y un rango para el epsilon de 0.001 a 3. Para min_samples vamos a usar un valor "estimado" que corresponde a 2 veces el número de features empleadas.

# %%
from sklearn.cluster import DBSCAN

# %%
for eps in np.arange(0.1, 3.0, 0.1):
    for min_samples in range(16,32):
        labels = DBSCAN(eps=eps,min_samples=min_samples).fit_predict(df_escalado)
        porcentaje_anomalias = (labels == -1).mean() * 100
        print(f"para eps = {eps}, min_samples= {min_samples}, el porcentaje de anomalías es {porcentaje_anomalias}")
# Out:
# para eps = 0.1, min_samples= 16, el porcentaje de anomalías es 100.0
# para eps = 0.1, min_samples= 17, el porcentaje de anomalías es 100.0
# para eps = 0.1, min_samples= 18, el porcentaje de anomalías es 100.0
# para eps = 0.1, min_samples= 19, el porcentaje de anomalías es 100.0
# para eps = 0.1, min_samples= 20, el porcentaje de anomalías es 100.0
# para eps = 0.1, min_samples= 21, el porcentaje de anomalías es 100.0
# para eps = 0.1, min_samples= 22, el porcentaje de anomalías es 100.0
# para eps = 0.1, min_samples= 23, el porcentaje de anomalías es 100.0
# para eps = 0.1, min_samples= 24, el porcentaje de anomalías es 100.0
# para eps = 0.1, min_samples= 25, el porcentaje de anomalías es 100.0
# para eps = 0.1, min_samples= 26, el porcentaje de anomalías es 100.0
# para eps = 0.1, min_samples= 27, el porcentaje de anomalías es 100.0
# para eps = 0.1, min_samples= 28, el porcentaje de anomalías es 100.0
# para eps = 0.1, min_samples= 29, el porcentaje de anomalías es 100.0
# para eps = 0.1, min_samples= 30, el porcentaje de anomalías es 100.0
# para eps = 0.1, min_samples= 31, el porcentaje de anomalías es 100.0
# para eps = 0.2, min_samples= 16, el porcentaje de anomalías es 100.0
# para eps = 0.2, min_samples= 17, el porcentaje de anomalías es 100.0
# para eps = 0.2, min_samples= 18, el porcentaje de anomalías es 100.0
# para eps = 0.2, min_samples= 19, el porcentaje de anomalías es 100.0
# para eps = 0.2, min_samples= 20, el porcentaje de anomalías es 100.0
# para eps = 0.2, min_samples= 21, el porcentaje de anomalías es 100.0
# para eps = 0.2, min_samples= 22, el porcentaje de anomalías es 100.0
# para eps = 0.2, min_samples= 23, el porcentaje de anomalías es 100.0
# para eps = 0.2, min_samples= 24, el porcentaje de anomalías es 100.0
# para eps = 0.2, min_samples= 25, el porcentaje de anomalías es 100.0
# para eps = 0.2, min_samples= 26, el porcentaje de anomalías es 100.0
# para eps = 0.2, min_samples= 27, el porcentaje de anomalías es 100.0
# para eps = 0.2, min_samples= 28, el porcentaje de anomalías es 100.0
# para eps = 0.2, min_samples= 29, el porcentaje de anomalías es 100.0
# para eps = 0.2, min_samples= 30, el porcentaje de anomalías es 100.0
# para eps = 0.2, min_samples= 31, el porcentaje de anomalías es 100.0
# para eps = 0.30000000000000004, min_samples= 16, el porcentaje de anomalías es 100.0
# para eps = 0.30000000000000004, min_samples= 17, el porcentaje de anomalías es 100.0
# para eps = 0.30000000000000004, min_samples= 18, el porcentaje de anomalías es 100.0
# para eps = 0.30000000000000004, min_samples= 19, el porcentaje de anomalías es 100.0
# para eps = 0.30000000000000004, min_samples= 20, el porcentaje de anomalías es 100.0
# para eps = 0.30000000000000004, min_samples= 21, el porcentaje de anomalías es 100.0
# para eps = 0.30000000000000004, min_samples= 22, el porcentaje de anomalías es 100.0
# para eps = 0.30000000000000004, min_samples= 23, el porcentaje de anomalías es 100.0
# para eps = 0.30000000000000004, min_samples= 24, el porcentaje de anomalías es 100.0
# para eps = 0.30000000000000004, min_samples= 25, el porcentaje de anomalías es 100.0
# para eps = 0.30000000000000004, min_samples= 26, el porcentaje de anomalías es 100.0
# para eps = 0.30000000000000004, min_samples= 27, el porcentaje de anomalías es 100.0
# para eps = 0.30000000000000004, min_samples= 28, el porcentaje de anomalías es 100.0
# para eps = 0.30000000000000004, min_samples= 29, el porcentaje de anomalías es 100.0
# para eps = 0.30000000000000004, min_samples= 30, el porcentaje de anomalías es 100.0
# para eps = 0.30000000000000004, min_samples= 31, el porcentaje de anomalías es 100.0
# para eps = 0.4, min_samples= 16, el porcentaje de anomalías es 100.0
# para eps = 0.4, min_samples= 17, el porcentaje de anomalías es 100.0
# para eps = 0.4, min_samples= 18, el porcentaje de anomalías es 100.0
# para eps = 0.4, min_samples= 19, el porcentaje de anomalías es 100.0
# para eps = 0.4, min_samples= 20, el porcentaje de anomalías es 100.0
# para eps = 0.4, min_samples= 21, el porcentaje de anomalías es 100.0
# para eps = 0.4, min_samples= 22, el porcentaje de anomalías es 100.0
# para eps = 0.4, min_samples= 23, el porcentaje de anomalías es 100.0
# para eps = 0.4, min_samples= 24, el porcentaje de anomalías es 100.0
# para eps = 0.4, min_samples= 25, el porcentaje de anomalías es 100.0
# para eps = 0.4, min_samples= 26, el porcentaje de anomalías es 100.0
# para eps = 0.4, min_samples= 27, el porcentaje de anomalías es 100.0
# para eps = 0.4, min_samples= 28, el porcentaje de anomalías es 100.0
# para eps = 0.4, min_samples= 29, el porcentaje de anomalías es 100.0
# para eps = 0.4, min_samples= 30, el porcentaje de anomalías es 100.0
# para eps = 0.4, min_samples= 31, el porcentaje de anomalías es 100.0
# para eps = 0.5, min_samples= 16, el porcentaje de anomalías es 100.0
# para eps = 0.5, min_samples= 17, el porcentaje de anomalías es 100.0
# para eps = 0.5, min_samples= 18, el porcentaje de anomalías es 100.0
# para eps = 0.5, min_samples= 19, el porcentaje de anomalías es 100.0
# para eps = 0.5, min_samples= 20, el porcentaje de anomalías es 100.0
# para eps = 0.5, min_samples= 21, el porcentaje de anomalías es 100.0
# para eps = 0.5, min_samples= 22, el porcentaje de anomalías es 100.0
# para eps = 0.5, min_samples= 23, el porcentaje de anomalías es 100.0
# para eps = 0.5, min_samples= 24, el porcentaje de anomalías es 100.0
# para eps = 0.5, min_samples= 25, el porcentaje de anomalías es 100.0
# para eps = 0.5, min_samples= 26, el porcentaje de anomalías es 100.0
# para eps = 0.5, min_samples= 27, el porcentaje de anomalías es 100.0
# para eps = 0.5, min_samples= 28, el porcentaje de anomalías es 100.0
# para eps = 0.5, min_samples= 29, el porcentaje de anomalías es 100.0
# para eps = 0.5, min_samples= 30, el porcentaje de anomalías es 100.0
# para eps = 0.5, min_samples= 31, el porcentaje de anomalías es 100.0
# para eps = 0.6, min_samples= 16, el porcentaje de anomalías es 100.0
# para eps = 0.6, min_samples= 17, el porcentaje de anomalías es 100.0
# para eps = 0.6, min_samples= 18, el porcentaje de anomalías es 100.0
# para eps = 0.6, min_samples= 19, el porcentaje de anomalías es 100.0
# para eps = 0.6, min_samples= 20, el porcentaje de anomalías es 100.0
# para eps = 0.6, min_samples= 21, el porcentaje de anomalías es 100.0
# para eps = 0.6, min_samples= 22, el porcentaje de anomalías es 100.0
# para eps = 0.6, min_samples= 23, el porcentaje de anomalías es 100.0
# para eps = 0.6, min_samples= 24, el porcentaje de anomalías es 100.0
# para eps = 0.6, min_samples= 25, el porcentaje de anomalías es 100.0
# para eps = 0.6, min_samples= 26, el porcentaje de anomalías es 100.0
# para eps = 0.6, min_samples= 27, el porcentaje de anomalías es 100.0
# para eps = 0.6, min_samples= 28, el porcentaje de anomalías es 100.0
# para eps = 0.6, min_samples= 29, el porcentaje de anomalías es 100.0
# para eps = 0.6, min_samples= 30, el porcentaje de anomalías es 100.0
# para eps = 0.6, min_samples= 31, el porcentaje de anomalías es 100.0
# para eps = 0.7000000000000001, min_samples= 16, el porcentaje de anomalías es 100.0
# para eps = 0.7000000000000001, min_samples= 17, el porcentaje de anomalías es 100.0
# para eps = 0.7000000000000001, min_samples= 18, el porcentaje de anomalías es 100.0
# para eps = 0.7000000000000001, min_samples= 19, el porcentaje de anomalías es 100.0
# para eps = 0.7000000000000001, min_samples= 20, el porcentaje de anomalías es 100.0
# para eps = 0.7000000000000001, min_samples= 21, el porcentaje de anomalías es 100.0
# para eps = 0.7000000000000001, min_samples= 22, el porcentaje de anomalías es 100.0
# para eps = 0.7000000000000001, min_samples= 23, el porcentaje de anomalías es 100.0
# para eps = 0.7000000000000001, min_samples= 24, el porcentaje de anomalías es 100.0
# para eps = 0.7000000000000001, min_samples= 25, el porcentaje de anomalías es 100.0
# para eps = 0.7000000000000001, min_samples= 26, el porcentaje de anomalías es 100.0
# para eps = 0.7000000000000001, min_samples= 27, el porcentaje de anomalías es 100.0
# para eps = 0.7000000000000001, min_samples= 28, el porcentaje de anomalías es 100.0
# para eps = 0.7000000000000001, min_samples= 29, el porcentaje de anomalías es 100.0
# para eps = 0.7000000000000001, min_samples= 30, el porcentaje de anomalías es 100.0
# para eps = 0.7000000000000001, min_samples= 31, el porcentaje de anomalías es 100.0
# para eps = 0.8, min_samples= 16, el porcentaje de anomalías es 100.0
# para eps = 0.8, min_samples= 17, el porcentaje de anomalías es 100.0
# para eps = 0.8, min_samples= 18, el porcentaje de anomalías es 100.0
# para eps = 0.8, min_samples= 19, el porcentaje de anomalías es 100.0
# para eps = 0.8, min_samples= 20, el porcentaje de anomalías es 100.0
# para eps = 0.8, min_samples= 21, el porcentaje de anomalías es 100.0
# para eps = 0.8, min_samples= 22, el porcentaje de anomalías es 100.0
# para eps = 0.8, min_samples= 23, el porcentaje de anomalías es 100.0
# para eps = 0.8, min_samples= 24, el porcentaje de anomalías es 100.0
# para eps = 0.8, min_samples= 25, el porcentaje de anomalías es 100.0
# para eps = 0.8, min_samples= 26, el porcentaje de anomalías es 100.0
# para eps = 0.8, min_samples= 27, el porcentaje de anomalías es 100.0
# para eps = 0.8, min_samples= 28, el porcentaje de anomalías es 100.0
# para eps = 0.8, min_samples= 29, el porcentaje de anomalías es 100.0
# para eps = 0.8, min_samples= 30, el porcentaje de anomalías es 100.0
# para eps = 0.8, min_samples= 31, el porcentaje de anomalías es 100.0
# para eps = 0.9, min_samples= 16, el porcentaje de anomalías es 95.22727272727273
# para eps = 0.9, min_samples= 17, el porcentaje de anomalías es 100.0
# para eps = 0.9, min_samples= 18, el porcentaje de anomalías es 100.0
# para eps = 0.9, min_samples= 19, el porcentaje de anomalías es 100.0
# para eps = 0.9, min_samples= 20, el porcentaje de anomalías es 100.0
# para eps = 0.9, min_samples= 21, el porcentaje de anomalías es 100.0
# para eps = 0.9, min_samples= 22, el porcentaje de anomalías es 100.0
# para eps = 0.9, min_samples= 23, el porcentaje de anomalías es 100.0
# para eps = 0.9, min_samples= 24, el porcentaje de anomalías es 100.0
# para eps = 0.9, min_samples= 25, el porcentaje de anomalías es 100.0
# para eps = 0.9, min_samples= 26, el porcentaje de anomalías es 100.0
# para eps = 0.9, min_samples= 27, el porcentaje de anomalías es 100.0
# para eps = 0.9, min_samples= 28, el porcentaje de anomalías es 100.0
# para eps = 0.9, min_samples= 29, el porcentaje de anomalías es 100.0
# para eps = 0.9, min_samples= 30, el porcentaje de anomalías es 100.0
# para eps = 0.9, min_samples= 31, el porcentaje de anomalías es 100.0
# para eps = 1.0, min_samples= 16, el porcentaje de anomalías es 78.63636363636364
# para eps = 1.0, min_samples= 17, el porcentaje de anomalías es 80.9090909090909
# para eps = 1.0, min_samples= 18, el porcentaje de anomalías es 81.5909090909091
# para eps = 1.0, min_samples= 19, el porcentaje de anomalías es 84.31818181818181
# para eps = 1.0, min_samples= 20, el porcentaje de anomalías es 85.68181818181819
# para eps = 1.0, min_samples= 21, el porcentaje de anomalías es 85.68181818181819
# para eps = 1.0, min_samples= 22, el porcentaje de anomalías es 86.36363636363636
# para eps = 1.0, min_samples= 23, el porcentaje de anomalías es 94.0909090909091
# para eps = 1.0, min_samples= 24, el porcentaje de anomalías es 94.0909090909091
# para eps = 1.0, min_samples= 25, el porcentaje de anomalías es 94.0909090909091
# para eps = 1.0, min_samples= 26, el porcentaje de anomalías es 94.0909090909091
# para eps = 1.0, min_samples= 27, el porcentaje de anomalías es 100.0
# para eps = 1.0, min_samples= 28, el porcentaje de anomalías es 100.0
# para eps = 1.0, min_samples= 29, el porcentaje de anomalías es 100.0
# para eps = 1.0, min_samples= 30, el porcentaje de anomalías es 100.0
# para eps = 1.0, min_samples= 31, el porcentaje de anomalías es 100.0
# para eps = 1.1, min_samples= 16, el porcentaje de anomalías es 65.9090909090909
# para eps = 1.1, min_samples= 17, el porcentaje de anomalías es 66.13636363636364
# para eps = 1.1, min_samples= 18, el porcentaje de anomalías es 67.27272727272727
# para eps = 1.1, min_samples= 19, el porcentaje de anomalías es 68.63636363636364
# para eps = 1.1, min_samples= 20, el porcentaje de anomalías es 69.54545454545455
# para eps = 1.1, min_samples= 21, el porcentaje de anomalías es 70.9090909090909
# para eps = 1.1, min_samples= 22, el porcentaje de anomalías es 71.81818181818181
# para eps = 1.1, min_samples= 23, el porcentaje de anomalías es 72.72727272727273
# para eps = 1.1, min_samples= 24, el porcentaje de anomalías es 74.31818181818181
# para eps = 1.1, min_samples= 25, el porcentaje de anomalías es 78.63636363636364
# para eps = 1.1, min_samples= 26, el porcentaje de anomalías es 81.36363636363636
# para eps = 1.1, min_samples= 27, el porcentaje de anomalías es 81.5909090909091
# para eps = 1.1, min_samples= 28, el porcentaje de anomalías es 83.4090909090909
# para eps = 1.1, min_samples= 29, el porcentaje de anomalías es 84.0909090909091
# para eps = 1.1, min_samples= 30, el porcentaje de anomalías es 92.27272727272727
# para eps = 1.1, min_samples= 31, el porcentaje de anomalías es 92.27272727272727
# para eps = 1.2000000000000002, min_samples= 16, el porcentaje de anomalías es 52.5
# para eps = 1.2000000000000002, min_samples= 17, el porcentaje de anomalías es 54.31818181818182
# para eps = 1.2000000000000002, min_samples= 18, el porcentaje de anomalías es 55.68181818181818
# para eps = 1.2000000000000002, min_samples= 19, el porcentaje de anomalías es 55.90909090909091
# para eps = 1.2000000000000002, min_samples= 20, el porcentaje de anomalías es 57.27272727272727
# para eps = 1.2000000000000002, min_samples= 21, el porcentaje de anomalías es 59.54545454545455
# para eps = 1.2000000000000002, min_samples= 22, el porcentaje de anomalías es 59.54545454545455
# para eps = 1.2000000000000002, min_samples= 23, el porcentaje de anomalías es 60.22727272727273
# para eps = 1.2000000000000002, min_samples= 24, el porcentaje de anomalías es 61.36363636363637
# para eps = 1.2000000000000002, min_samples= 25, el porcentaje de anomalías es 62.272727272727266
# para eps = 1.2000000000000002, min_samples= 26, el porcentaje de anomalías es 62.727272727272734
# para eps = 1.2000000000000002, min_samples= 27, el porcentaje de anomalías es 63.40909090909091
# para eps = 1.2000000000000002, min_samples= 28, el porcentaje de anomalías es 64.31818181818181
# para eps = 1.2000000000000002, min_samples= 29, el porcentaje de anomalías es 66.13636363636364
# para eps = 1.2000000000000002, min_samples= 30, el porcentaje de anomalías es 68.18181818181817
# para eps = 1.2000000000000002, min_samples= 31, el porcentaje de anomalías es 69.54545454545455
# para eps = 1.3000000000000003, min_samples= 16, el porcentaje de anomalías es 39.09090909090909
# para eps = 1.3000000000000003, min_samples= 17, el porcentaje de anomalías es 40.68181818181818
# para eps = 1.3000000000000003, min_samples= 18, el porcentaje de anomalías es 43.63636363636363
# para eps = 1.3000000000000003, min_samples= 19, el porcentaje de anomalías es 45.45454545454545
# para eps = 1.3000000000000003, min_samples= 20, el porcentaje de anomalías es 46.36363636363636
# para eps = 1.3000000000000003, min_samples= 21, el porcentaje de anomalías es 47.04545454545455
# para eps = 1.3000000000000003, min_samples= 22, el porcentaje de anomalías es 48.18181818181818
# para eps = 1.3000000000000003, min_samples= 23, el porcentaje de anomalías es 48.18181818181818
# para eps = 1.3000000000000003, min_samples= 24, el porcentaje de anomalías es 50.0
# para eps = 1.3000000000000003, min_samples= 25, el porcentaje de anomalías es 50.90909090909091
# para eps = 1.3000000000000003, min_samples= 26, el porcentaje de anomalías es 51.13636363636363
# para eps = 1.3000000000000003, min_samples= 27, el porcentaje de anomalías es 52.27272727272727
# para eps = 1.3000000000000003, min_samples= 28, el porcentaje de anomalías es 54.54545454545454
# para eps = 1.3000000000000003, min_samples= 29, el porcentaje de anomalías es 54.77272727272727
# para eps = 1.3000000000000003, min_samples= 30, el porcentaje de anomalías es 55.45454545454545
# para eps = 1.3000000000000003, min_samples= 31, el porcentaje de anomalías es 55.68181818181818
# para eps = 1.4000000000000001, min_samples= 16, el porcentaje de anomalías es 31.590909090909093
# para eps = 1.4000000000000001, min_samples= 17, el porcentaje de anomalías es 31.590909090909093
# para eps = 1.4000000000000001, min_samples= 18, el porcentaje de anomalías es 31.590909090909093
# para eps = 1.4000000000000001, min_samples= 19, el porcentaje de anomalías es 33.63636363636363
# para eps = 1.4000000000000001, min_samples= 20, el porcentaje de anomalías es 34.54545454545455
# para eps = 1.4000000000000001, min_samples= 21, el porcentaje de anomalías es 35.68181818181818
# para eps = 1.4000000000000001, min_samples= 22, el porcentaje de anomalías es 36.59090909090909
# para eps = 1.4000000000000001, min_samples= 23, el porcentaje de anomalías es 37.04545454545455
# para eps = 1.4000000000000001, min_samples= 24, el porcentaje de anomalías es 39.31818181818182
# para eps = 1.4000000000000001, min_samples= 25, el porcentaje de anomalías es 40.0
# para eps = 1.4000000000000001, min_samples= 26, el porcentaje de anomalías es 41.81818181818181
# para eps = 1.4000000000000001, min_samples= 27, el porcentaje de anomalías es 43.40909090909091
# para eps = 1.4000000000000001, min_samples= 28, el porcentaje de anomalías es 43.63636363636363
# para eps = 1.4000000000000001, min_samples= 29, el porcentaje de anomalías es 44.77272727272727
# para eps = 1.4000000000000001, min_samples= 30, el porcentaje de anomalías es 45.0
# para eps = 1.4000000000000001, min_samples= 31, el porcentaje de anomalías es 45.0
# para eps = 1.5000000000000002, min_samples= 16, el porcentaje de anomalías es 25.227272727272727
# para eps = 1.5000000000000002, min_samples= 17, el porcentaje de anomalías es 25.681818181818183
# para eps = 1.5000000000000002, min_samples= 18, el porcentaje de anomalías es 25.90909090909091
# para eps = 1.5000000000000002, min_samples= 19, el porcentaje de anomalías es 25.90909090909091
# para eps = 1.5000000000000002, min_samples= 20, el porcentaje de anomalías es 26.81818181818182
# para eps = 1.5000000000000002, min_samples= 21, el porcentaje de anomalías es 27.045454545454543
# para eps = 1.5000000000000002, min_samples= 22, el porcentaje de anomalías es 27.954545454545453
# para eps = 1.5000000000000002, min_samples= 23, el porcentaje de anomalías es 28.18181818181818
# para eps = 1.5000000000000002, min_samples= 24, el porcentaje de anomalías es 28.18181818181818
# para eps = 1.5000000000000002, min_samples= 25, el porcentaje de anomalías es 29.318181818181817
# para eps = 1.5000000000000002, min_samples= 26, el porcentaje de anomalías es 30.227272727272727
# para eps = 1.5000000000000002, min_samples= 27, el porcentaje de anomalías es 30.227272727272727
# para eps = 1.5000000000000002, min_samples= 28, el porcentaje de anomalías es 30.454545454545457
# para eps = 1.5000000000000002, min_samples= 29, el porcentaje de anomalías es 30.454545454545457
# para eps = 1.5000000000000002, min_samples= 30, el porcentaje de anomalías es 30.909090909090907
# para eps = 1.5000000000000002, min_samples= 31, el porcentaje de anomalías es 32.72727272727273
# para eps = 1.6, min_samples= 16, el porcentaje de anomalías es 19.090909090909093
# para eps = 1.6, min_samples= 17, el porcentaje de anomalías es 19.090909090909093
# para eps = 1.6, min_samples= 18, el porcentaje de anomalías es 20.227272727272727
# para eps = 1.6, min_samples= 19, el porcentaje de anomalías es 20.454545454545457
# para eps = 1.6, min_samples= 20, el porcentaje de anomalías es 21.818181818181817
# para eps = 1.6, min_samples= 21, el porcentaje de anomalías es 22.5
# para eps = 1.6, min_samples= 22, el porcentaje de anomalías es 24.09090909090909
# para eps = 1.6, min_samples= 23, el porcentaje de anomalías es 24.09090909090909
# para eps = 1.6, min_samples= 24, el porcentaje de anomalías es 24.09090909090909
# para eps = 1.6, min_samples= 25, el porcentaje de anomalías es 24.09090909090909
# para eps = 1.6, min_samples= 26, el porcentaje de anomalías es 24.31818181818182
# para eps = 1.6, min_samples= 27, el porcentaje de anomalías es 24.31818181818182
# para eps = 1.6, min_samples= 28, el porcentaje de anomalías es 24.772727272727273
# para eps = 1.6, min_samples= 29, el porcentaje de anomalías es 24.772727272727273
# para eps = 1.6, min_samples= 30, el porcentaje de anomalías es 25.227272727272727
# para eps = 1.6, min_samples= 31, el porcentaje de anomalías es 25.90909090909091
# para eps = 1.7000000000000002, min_samples= 16, el porcentaje de anomalías es 14.09090909090909
# para eps = 1.7000000000000002, min_samples= 17, el porcentaje de anomalías es 14.318181818181818
# para eps = 1.7000000000000002, min_samples= 18, el porcentaje de anomalías es 15.227272727272728
# para eps = 1.7000000000000002, min_samples= 19, el porcentaje de anomalías es 15.227272727272728
# para eps = 1.7000000000000002, min_samples= 20, el porcentaje de anomalías es 15.681818181818183
# para eps = 1.7000000000000002, min_samples= 21, el porcentaje de anomalías es 16.818181818181817
# para eps = 1.7000000000000002, min_samples= 22, el porcentaje de anomalías es 17.272727272727273
# para eps = 1.7000000000000002, min_samples= 23, el porcentaje de anomalías es 17.727272727272727
# para eps = 1.7000000000000002, min_samples= 24, el porcentaje de anomalías es 17.727272727272727
# para eps = 1.7000000000000002, min_samples= 25, el porcentaje de anomalías es 19.318181818181817
# para eps = 1.7000000000000002, min_samples= 26, el porcentaje de anomalías es 19.318181818181817
# para eps = 1.7000000000000002, min_samples= 27, el porcentaje de anomalías es 19.318181818181817
# para eps = 1.7000000000000002, min_samples= 28, el porcentaje de anomalías es 19.545454545454547
# para eps = 1.7000000000000002, min_samples= 29, el porcentaje de anomalías es 20.454545454545457
# para eps = 1.7000000000000002, min_samples= 30, el porcentaje de anomalías es 20.454545454545457
# para eps = 1.7000000000000002, min_samples= 31, el porcentaje de anomalías es 20.454545454545457
# para eps = 1.8000000000000003, min_samples= 16, el porcentaje de anomalías es 10.681818181818182
# para eps = 1.8000000000000003, min_samples= 17, el porcentaje de anomalías es 10.909090909090908
# para eps = 1.8000000000000003, min_samples= 18, el porcentaje de anomalías es 11.136363636363637
# para eps = 1.8000000000000003, min_samples= 19, el porcentaje de anomalías es 11.363636363636363
# para eps = 1.8000000000000003, min_samples= 20, el porcentaje de anomalías es 11.59090909090909
# para eps = 1.8000000000000003, min_samples= 21, el porcentaje de anomalías es 11.59090909090909
# para eps = 1.8000000000000003, min_samples= 22, el porcentaje de anomalías es 12.272727272727273
# para eps = 1.8000000000000003, min_samples= 23, el porcentaje de anomalías es 12.272727272727273
# para eps = 1.8000000000000003, min_samples= 24, el porcentaje de anomalías es 12.272727272727273
# para eps = 1.8000000000000003, min_samples= 25, el porcentaje de anomalías es 12.727272727272727
# para eps = 1.8000000000000003, min_samples= 26, el porcentaje de anomalías es 12.954545454545455
# para eps = 1.8000000000000003, min_samples= 27, el porcentaje de anomalías es 13.863636363636363
# para eps = 1.8000000000000003, min_samples= 28, el porcentaje de anomalías es 13.863636363636363
# para eps = 1.8000000000000003, min_samples= 29, el porcentaje de anomalías es 14.318181818181818
# para eps = 1.8000000000000003, min_samples= 30, el porcentaje de anomalías es 16.136363636363637
# para eps = 1.8000000000000003, min_samples= 31, el porcentaje de anomalías es 16.590909090909093
# para eps = 1.9000000000000001, min_samples= 16, el porcentaje de anomalías es 7.727272727272727
# para eps = 1.9000000000000001, min_samples= 17, el porcentaje de anomalías es 7.954545454545454
# para eps = 1.9000000000000001, min_samples= 18, el porcentaje de anomalías es 7.954545454545454
# para eps = 1.9000000000000001, min_samples= 19, el porcentaje de anomalías es 8.409090909090908
# para eps = 1.9000000000000001, min_samples= 20, el porcentaje de anomalías es 8.636363636363637
# para eps = 1.9000000000000001, min_samples= 21, el porcentaje de anomalías es 8.863636363636363
# para eps = 1.9000000000000001, min_samples= 22, el porcentaje de anomalías es 9.318181818181818
# para eps = 1.9000000000000001, min_samples= 23, el porcentaje de anomalías es 9.318181818181818
# para eps = 1.9000000000000001, min_samples= 24, el porcentaje de anomalías es 9.318181818181818
# para eps = 1.9000000000000001, min_samples= 25, el porcentaje de anomalías es 9.772727272727273
# para eps = 1.9000000000000001, min_samples= 26, el porcentaje de anomalías es 10.0
# para eps = 1.9000000000000001, min_samples= 27, el porcentaje de anomalías es 10.0
# para eps = 1.9000000000000001, min_samples= 28, el porcentaje de anomalías es 10.227272727272728
# para eps = 1.9000000000000001, min_samples= 29, el porcentaje de anomalías es 10.227272727272728
# para eps = 1.9000000000000001, min_samples= 30, el porcentaje de anomalías es 10.909090909090908
# para eps = 1.9000000000000001, min_samples= 31, el porcentaje de anomalías es 10.909090909090908
# para eps = 2.0, min_samples= 16, el porcentaje de anomalías es 6.363636363636363
# para eps = 2.0, min_samples= 17, el porcentaje de anomalías es 6.59090909090909
# para eps = 2.0, min_samples= 18, el porcentaje de anomalías es 6.59090909090909
# para eps = 2.0, min_samples= 19, el porcentaje de anomalías es 6.59090909090909
# para eps = 2.0, min_samples= 20, el porcentaje de anomalías es 6.59090909090909
# para eps = 2.0, min_samples= 21, el porcentaje de anomalías es 6.59090909090909
# para eps = 2.0, min_samples= 22, el porcentaje de anomalías es 6.59090909090909
# para eps = 2.0, min_samples= 23, el porcentaje de anomalías es 6.59090909090909
# para eps = 2.0, min_samples= 24, el porcentaje de anomalías es 7.045454545454545
# para eps = 2.0, min_samples= 25, el porcentaje de anomalías es 7.045454545454545
# para eps = 2.0, min_samples= 26, el porcentaje de anomalías es 7.045454545454545
# para eps = 2.0, min_samples= 27, el porcentaje de anomalías es 7.045454545454545
# para eps = 2.0, min_samples= 28, el porcentaje de anomalías es 7.045454545454545
# para eps = 2.0, min_samples= 29, el porcentaje de anomalías es 7.5
# para eps = 2.0, min_samples= 30, el porcentaje de anomalías es 7.5
# para eps = 2.0, min_samples= 31, el porcentaje de anomalías es 7.727272727272727
# para eps = 2.1, min_samples= 16, el porcentaje de anomalías es 5.0
# para eps = 2.1, min_samples= 17, el porcentaje de anomalías es 5.0
# para eps = 2.1, min_samples= 18, el porcentaje de anomalías es 5.0
# para eps = 2.1, min_samples= 19, el porcentaje de anomalías es 5.227272727272727
# para eps = 2.1, min_samples= 20, el porcentaje de anomalías es 5.227272727272727
# para eps = 2.1, min_samples= 21, el porcentaje de anomalías es 5.681818181818182
# para eps = 2.1, min_samples= 22, el porcentaje de anomalías es 5.681818181818182
# para eps = 2.1, min_samples= 23, el porcentaje de anomalías es 5.681818181818182
# para eps = 2.1, min_samples= 24, el porcentaje de anomalías es 5.681818181818182
# para eps = 2.1, min_samples= 25, el porcentaje de anomalías es 5.681818181818182
# para eps = 2.1, min_samples= 26, el porcentaje de anomalías es 5.681818181818182
# para eps = 2.1, min_samples= 27, el porcentaje de anomalías es 5.681818181818182
# para eps = 2.1, min_samples= 28, el porcentaje de anomalías es 5.681818181818182
# para eps = 2.1, min_samples= 29, el porcentaje de anomalías es 5.681818181818182
# para eps = 2.1, min_samples= 30, el porcentaje de anomalías es 5.909090909090909
# para eps = 2.1, min_samples= 31, el porcentaje de anomalías es 5.909090909090909
# para eps = 2.2, min_samples= 16, el porcentaje de anomalías es 3.6363636363636362
# para eps = 2.2, min_samples= 17, el porcentaje de anomalías es 3.6363636363636362
# para eps = 2.2, min_samples= 18, el porcentaje de anomalías es 3.6363636363636362
# para eps = 2.2, min_samples= 19, el porcentaje de anomalías es 3.8636363636363633
# para eps = 2.2, min_samples= 20, el porcentaje de anomalías es 3.8636363636363633
# para eps = 2.2, min_samples= 21, el porcentaje de anomalías es 3.8636363636363633
# para eps = 2.2, min_samples= 22, el porcentaje de anomalías es 4.545454545454546
# para eps = 2.2, min_samples= 23, el porcentaje de anomalías es 4.545454545454546
# para eps = 2.2, min_samples= 24, el porcentaje de anomalías es 4.545454545454546
# para eps = 2.2, min_samples= 25, el porcentaje de anomalías es 4.545454545454546
# para eps = 2.2, min_samples= 26, el porcentaje de anomalías es 4.545454545454546
# para eps = 2.2, min_samples= 27, el porcentaje de anomalías es 4.545454545454546
# para eps = 2.2, min_samples= 28, el porcentaje de anomalías es 4.772727272727273
# para eps = 2.2, min_samples= 29, el porcentaje de anomalías es 4.772727272727273
# para eps = 2.2, min_samples= 30, el porcentaje de anomalías es 4.772727272727273
# para eps = 2.2, min_samples= 31, el porcentaje de anomalías es 5.0
# para eps = 2.3000000000000003, min_samples= 16, el porcentaje de anomalías es 3.4090909090909087
# para eps = 2.3000000000000003, min_samples= 17, el porcentaje de anomalías es 3.4090909090909087
# para eps = 2.3000000000000003, min_samples= 18, el porcentaje de anomalías es 3.4090909090909087
# para eps = 2.3000000000000003, min_samples= 19, el porcentaje de anomalías es 3.4090909090909087
# para eps = 2.3000000000000003, min_samples= 20, el porcentaje de anomalías es 3.4090909090909087
# para eps = 2.3000000000000003, min_samples= 21, el porcentaje de anomalías es 3.4090909090909087
# para eps = 2.3000000000000003, min_samples= 22, el porcentaje de anomalías es 3.6363636363636362
# para eps = 2.3000000000000003, min_samples= 23, el porcentaje de anomalías es 3.6363636363636362
# para eps = 2.3000000000000003, min_samples= 24, el porcentaje de anomalías es 3.8636363636363633
# para eps = 2.3000000000000003, min_samples= 25, el porcentaje de anomalías es 4.090909090909091
# para eps = 2.3000000000000003, min_samples= 26, el porcentaje de anomalías es 4.090909090909091
# para eps = 2.3000000000000003, min_samples= 27, el porcentaje de anomalías es 4.090909090909091
# para eps = 2.3000000000000003, min_samples= 28, el porcentaje de anomalías es 4.090909090909091
# para eps = 2.3000000000000003, min_samples= 29, el porcentaje de anomalías es 4.090909090909091
# para eps = 2.3000000000000003, min_samples= 30, el porcentaje de anomalías es 4.090909090909091
# para eps = 2.3000000000000003, min_samples= 31, el porcentaje de anomalías es 4.090909090909091
# para eps = 2.4000000000000004, min_samples= 16, el porcentaje de anomalías es 2.9545454545454546
# para eps = 2.4000000000000004, min_samples= 17, el porcentaje de anomalías es 2.9545454545454546
# para eps = 2.4000000000000004, min_samples= 18, el porcentaje de anomalías es 2.9545454545454546
# para eps = 2.4000000000000004, min_samples= 19, el porcentaje de anomalías es 2.9545454545454546
# para eps = 2.4000000000000004, min_samples= 20, el porcentaje de anomalías es 2.9545454545454546
# para eps = 2.4000000000000004, min_samples= 21, el porcentaje de anomalías es 2.9545454545454546
# para eps = 2.4000000000000004, min_samples= 22, el porcentaje de anomalías es 2.9545454545454546
# para eps = 2.4000000000000004, min_samples= 23, el porcentaje de anomalías es 2.9545454545454546
# para eps = 2.4000000000000004, min_samples= 24, el porcentaje de anomalías es 2.9545454545454546
# para eps = 2.4000000000000004, min_samples= 25, el porcentaje de anomalías es 2.9545454545454546
# para eps = 2.4000000000000004, min_samples= 26, el porcentaje de anomalías es 2.9545454545454546
# para eps = 2.4000000000000004, min_samples= 27, el porcentaje de anomalías es 2.9545454545454546
# para eps = 2.4000000000000004, min_samples= 28, el porcentaje de anomalías es 3.1818181818181817
# para eps = 2.4000000000000004, min_samples= 29, el porcentaje de anomalías es 3.4090909090909087
# para eps = 2.4000000000000004, min_samples= 30, el porcentaje de anomalías es 3.4090909090909087
# para eps = 2.4000000000000004, min_samples= 31, el porcentaje de anomalías es 3.4090909090909087
# para eps = 2.5000000000000004, min_samples= 16, el porcentaje de anomalías es 2.5
# para eps = 2.5000000000000004, min_samples= 17, el porcentaje de anomalías es 2.5
# para eps = 2.5000000000000004, min_samples= 18, el porcentaje de anomalías es 2.727272727272727
# para eps = 2.5000000000000004, min_samples= 19, el porcentaje de anomalías es 2.727272727272727
# para eps = 2.5000000000000004, min_samples= 20, el porcentaje de anomalías es 2.727272727272727
# para eps = 2.5000000000000004, min_samples= 21, el porcentaje de anomalías es 2.727272727272727
# para eps = 2.5000000000000004, min_samples= 22, el porcentaje de anomalías es 2.727272727272727
# para eps = 2.5000000000000004, min_samples= 23, el porcentaje de anomalías es 2.727272727272727
# para eps = 2.5000000000000004, min_samples= 24, el porcentaje de anomalías es 2.727272727272727
# para eps = 2.5000000000000004, min_samples= 25, el porcentaje de anomalías es 2.727272727272727
# para eps = 2.5000000000000004, min_samples= 26, el porcentaje de anomalías es 2.727272727272727
# para eps = 2.5000000000000004, min_samples= 27, el porcentaje de anomalías es 2.727272727272727
# para eps = 2.5000000000000004, min_samples= 28, el porcentaje de anomalías es 2.727272727272727
# para eps = 2.5000000000000004, min_samples= 29, el porcentaje de anomalías es 2.727272727272727
# para eps = 2.5000000000000004, min_samples= 30, el porcentaje de anomalías es 2.727272727272727
# para eps = 2.5000000000000004, min_samples= 31, el porcentaje de anomalías es 2.9545454545454546
# para eps = 2.6, min_samples= 16, el porcentaje de anomalías es 2.0454545454545454
# para eps = 2.6, min_samples= 17, el porcentaje de anomalías es 2.0454545454545454
# para eps = 2.6, min_samples= 18, el porcentaje de anomalías es 2.272727272727273
# para eps = 2.6, min_samples= 19, el porcentaje de anomalías es 2.272727272727273
# para eps = 2.6, min_samples= 20, el porcentaje de anomalías es 2.272727272727273
# para eps = 2.6, min_samples= 21, el porcentaje de anomalías es 2.272727272727273
# para eps = 2.6, min_samples= 22, el porcentaje de anomalías es 2.5
# para eps = 2.6, min_samples= 23, el porcentaje de anomalías es 2.5
# para eps = 2.6, min_samples= 24, el porcentaje de anomalías es 2.5
# para eps = 2.6, min_samples= 25, el porcentaje de anomalías es 2.5
# para eps = 2.6, min_samples= 26, el porcentaje de anomalías es 2.5
# para eps = 2.6, min_samples= 27, el porcentaje de anomalías es 2.5
# para eps = 2.6, min_samples= 28, el porcentaje de anomalías es 2.5
# para eps = 2.6, min_samples= 29, el porcentaje de anomalías es 2.5
# para eps = 2.6, min_samples= 30, el porcentaje de anomalías es 2.5
# para eps = 2.6, min_samples= 31, el porcentaje de anomalías es 2.5
# para eps = 2.7, min_samples= 16, el porcentaje de anomalías es 1.8181818181818181
# para eps = 2.7, min_samples= 17, el porcentaje de anomalías es 1.8181818181818181
# para eps = 2.7, min_samples= 18, el porcentaje de anomalías es 1.8181818181818181
# para eps = 2.7, min_samples= 19, el porcentaje de anomalías es 1.8181818181818181
# para eps = 2.7, min_samples= 20, el porcentaje de anomalías es 1.8181818181818181
# para eps = 2.7, min_samples= 21, el porcentaje de anomalías es 1.8181818181818181
# para eps = 2.7, min_samples= 22, el porcentaje de anomalías es 1.8181818181818181
# para eps = 2.7, min_samples= 23, el porcentaje de anomalías es 1.8181818181818181
# para eps = 2.7, min_samples= 24, el porcentaje de anomalías es 1.8181818181818181
# para eps = 2.7, min_samples= 25, el porcentaje de anomalías es 1.8181818181818181
# para eps = 2.7, min_samples= 26, el porcentaje de anomalías es 1.8181818181818181
# para eps = 2.7, min_samples= 27, el porcentaje de anomalías es 2.0454545454545454
# para eps = 2.7, min_samples= 28, el porcentaje de anomalías es 2.0454545454545454
# para eps = 2.7, min_samples= 29, el porcentaje de anomalías es 2.0454545454545454
# para eps = 2.7, min_samples= 30, el porcentaje de anomalías es 2.0454545454545454
# para eps = 2.7, min_samples= 31, el porcentaje de anomalías es 2.0454545454545454
# para eps = 2.8000000000000003, min_samples= 16, el porcentaje de anomalías es 1.1363636363636365
# para eps = 2.8000000000000003, min_samples= 17, el porcentaje de anomalías es 1.1363636363636365
# para eps = 2.8000000000000003, min_samples= 18, el porcentaje de anomalías es 1.1363636363636365
# para eps = 2.8000000000000003, min_samples= 19, el porcentaje de anomalías es 1.5909090909090908
# para eps = 2.8000000000000003, min_samples= 20, el porcentaje de anomalías es 1.5909090909090908
# para eps = 2.8000000000000003, min_samples= 21, el porcentaje de anomalías es 1.5909090909090908
# para eps = 2.8000000000000003, min_samples= 22, el porcentaje de anomalías es 1.5909090909090908
# para eps = 2.8000000000000003, min_samples= 23, el porcentaje de anomalías es 1.5909090909090908
# para eps = 2.8000000000000003, min_samples= 24, el porcentaje de anomalías es 1.5909090909090908
# para eps = 2.8000000000000003, min_samples= 25, el porcentaje de anomalías es 1.5909090909090908
# para eps = 2.8000000000000003, min_samples= 26, el porcentaje de anomalías es 1.5909090909090908
# para eps = 2.8000000000000003, min_samples= 27, el porcentaje de anomalías es 1.5909090909090908
# para eps = 2.8000000000000003, min_samples= 28, el porcentaje de anomalías es 1.5909090909090908
# para eps = 2.8000000000000003, min_samples= 29, el porcentaje de anomalías es 1.5909090909090908
# para eps = 2.8000000000000003, min_samples= 30, el porcentaje de anomalías es 1.5909090909090908
# para eps = 2.8000000000000003, min_samples= 31, el porcentaje de anomalías es 1.8181818181818181
# para eps = 2.9000000000000004, min_samples= 16, el porcentaje de anomalías es 0.9090909090909091
# para eps = 2.9000000000000004, min_samples= 17, el porcentaje de anomalías es 1.1363636363636365
# para eps = 2.9000000000000004, min_samples= 18, el porcentaje de anomalías es 1.1363636363636365
# para eps = 2.9000000000000004, min_samples= 19, el porcentaje de anomalías es 1.1363636363636365
# para eps = 2.9000000000000004, min_samples= 20, el porcentaje de anomalías es 1.1363636363636365
# para eps = 2.9000000000000004, min_samples= 21, el porcentaje de anomalías es 1.1363636363636365
# para eps = 2.9000000000000004, min_samples= 22, el porcentaje de anomalías es 1.5909090909090908
# para eps = 2.9000000000000004, min_samples= 23, el porcentaje de anomalías es 1.5909090909090908
# para eps = 2.9000000000000004, min_samples= 24, el porcentaje de anomalías es 1.5909090909090908
# para eps = 2.9000000000000004, min_samples= 25, el porcentaje de anomalías es 1.5909090909090908
# para eps = 2.9000000000000004, min_samples= 26, el porcentaje de anomalías es 1.5909090909090908
# para eps = 2.9000000000000004, min_samples= 27, el porcentaje de anomalías es 1.5909090909090908
# para eps = 2.9000000000000004, min_samples= 28, el porcentaje de anomalías es 1.5909090909090908
# para eps = 2.9000000000000004, min_samples= 29, el porcentaje de anomalías es 1.5909090909090908
# para eps = 2.9000000000000004, min_samples= 30, el porcentaje de anomalías es 1.5909090909090908
# para eps = 2.9000000000000004, min_samples= 31, el porcentaje de anomalías es 1.5909090909090908

# %% [markdown]
# para eps = 1.9000000000000001, min_samples= 16, el porcentaje de anomalías es 7.727272727272727

# %% [markdown]
# ### Ejercicio 10
#
# Entrena un clustering DBSCAN con el valor que hayas encontrado como mejor en el ejercicio anterior (si no has visto claramente un valor, usa eps = 2) y `min_samples` a dos veces el número de features empleadas.

# %%
dbscan = DBSCAN(eps=1.9, min_samples=16)

# %% [markdown]
# ### Ejercicio 11
#
# Agrega las etiquetas generadas con DBSCAN a tu dataframe original e interpreta los resultados (observa el número de etiquetas, recuerda que -1 no es un cluster son anomalías o outliers) luego contesta a: ¿Qué grupos o patrones fué capaz de capturar el DBSCAN? (Haz las tablas de contingencia de las etiquetas con las dos variables categóricas, por separado, por ejemplo y a partir de ahí justifica tu respuesta)

# %%
df["predicciones"]=dbscan.fit_predict(df_escalado)

# %%
df["predicciones"].value_counts()
# Out:
# predicciones
#  0    406
# -1     34
# Name: count, dtype: int64

# %%
df
# Out:
#      Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 0          2       3  12669   9656     7561     214              2674
# 1          2       3   7057   9810     9568    1762              3293
# 2          2       3   6353   8808     7684    2405              3516
# 3          1       3  13265   1196     4221    6404               507
# 4          2       3  22615   5410     7198    3915              1777
# ..       ...     ...    ...    ...      ...     ...               ...
# 435        1       3  29703  12051    16027   13135               182
# 436        1       3  39228   1431      764    4510                93
# 437        2       3  14531  15488    30243     437             14841
# 438        1       3  10290   1981     2232    1038               168
# 439        1       3   2787   1698     2510      65               477
#
#      Delicassen  predicciones
# 0          1338             0
# 1          1776             0
# 2          7844             0
# 3          1788             0
# 4          5185             0
# ..          ...           ...
# 435        2204             0
# 436        2346             0
# 437        1867             0
# 438        2125             0
# 439          52             0
#
# [440 rows x 9 columns]

# %%
tabla_cat1 = pd.crosstab(df["predicciones"], df["Channel"])
print(tabla_cat1)
# Out:
# Channel         1    2
# predicciones
# -1             26    8
#  0            272  134

# %%
tabla_cat1 = pd.crosstab(df["predicciones"], df["Region"])
print(tabla_cat1)
# Out:
# Region         1   2    3
# predicciones
# -1             9   3   22
#  0            68  44  294
